# %%
import numpy as np
import pandas as pd
import recsys as rs
import SLIM_BPR_PY as SLIMBPR

# %%
dataset = pd.read_csv('Data/train_final.csv','\t')
tr_info = pd.read_csv('Data/tracks_final.csv','\t')

# %%
IX_items, _, IX_tgt_playlists, _ = rs.create_sparse_indexes(tracks_info=tr_info, playlists=dataset)

# %%
URM = rs.create_tgt_URM(IX_tgt_playlists, IX_items, dataset)
URM = URM.tocsr()
# Out:
# Calculated 0 users ratings over 45649
# Calculated 1000 users ratings over 45649
# Calculated 2000 users ratings over 45649
# Calculated 3000 users ratings over 45649
# Calculated 4000 users ratings over 45649
# Calculated 5000 users ratings over 45649
# Calculated 6000 users ratings over 45649
# Calculated 7000 users ratings over 45649
# Calculated 8000 users ratings over 45649
# Calculated 9000 users ratings over 45649
# Calculated 10000 users ratings over 45649
# Calculated 11000 users ratings over 45649
# Calculated 12000 users ratings over 45649
# Calculated 13000 users ratings over 45649
# Calculated 14000 users ratings over 45649
# Calculated 15000 users ratings over 45649
# Calculated 16000 users ratings over 45649
# Calculated 17000 users ratings over 45649
# Calculated 18000 users ratings over 45649
# Calculated 19000 users ratings over 45649
# Calculated 20000 users ratings over 45649
# Calculated 21000 users ratings over 45649
# Calculated 22000 users ratings over 45649
# Calculated 23000 users ratings over 45649
# Calculated 24000 users ratings over 45649
# Calculated 25000 users ratings over 45649
# Calculated 26000 users ratings over 45649
# Calculated 27000 users ratings over 45649
# Calculated 28000 users ratings over 45649
# Calculated 29000 users ratings over 45649
# Calculated 30000 users ratings over 45649
# Calculated 31000 users ratings over 45649
# Calculated 32000 users ratings over 45649
# Calculated 33000 users ratings over 45649
# Calculated 34000 users ratings over 45649
# Calculated 35000 users ratings over 45649
# Calculated 36000 users ratings over 45649
# Calculated 37000 users ratings over 45649
# Calculated 38000 users ratings over 45649
# Calculated 39000 users ratings over 45649
# Calculated 40000 users ratings over 45649
# Calculated 41000 users ratings over 45649
# Calculated 42000 users ratings over 45649
# Calculated 43000 users ratings over 45649
# Calculated 44000 users ratings over 45649
# Calculated 45000 users ratings over 45649

# %%
recommender = SLIMBPR.SLIM_BPR_Python(URM)
recommender.fit(topK=20)

# %%
recommendetions = np.array([])
for p in IX_tgt_playlists.values:
            avg_sims = URM[p,:].dot(recommender.S).toarray().ravel()
            top = rs.top5_outside_playlist(avg_sims, p, train, IX_tgt_playlists, IX_tgt_items)
            recommendetions = np.append(recommendetions, rs.sub_format(top))
            if (p % 1000 == 0):
                print('Recommended ' + str(p) + ' users over ' + str(IX_tgt_playlists.values.shape[0]))
print(recommendetions.shape[0])
print(tgt_playlists['playlist_id'].shape[0])
print(IX_tgt_playlists.shape[0])
recs = pd.DataFrame({'playlist_id' : IX_tgt_playlists.index.values, 'track_ids' : recommendetions})
recs
# Out:
# Recommended 0 users over 84
# 84
# 84
# 84
#     playlist_id                                track_ids
# 0       7670304     424298 2720582 1647509 335496 209196
# 1       7559928  1914337 2637110 1639389 3006129 1088475
# 2       7623847  1374934 1916878 3186602 2448296 2249460
